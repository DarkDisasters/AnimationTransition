# %%
import pandas as pd
import numpy as np

dfCountry = pd.read_csv('./LPI_csv/LPICountry.csv')
dfData = pd.read_csv('./LPI_csv/LPIData.csv')

dataDict = {}

countryCodeList = dfCountry['Country Code'].tolist()

for i in range(len(countryCodeList)):
    dataDict[countryCodeList[i]] = {}

datalist = np.array(df).tolist()
# print('datalist',datalist)
for i in range(len(datalist)):
#     dataDict[datalist[i][1]][datalist[i][3]] = [datalist[i][4]]     #07
#     dataDict[datalist[i][1]][datalist[i][3]] = [datalist[i][5]]       #10
#     dataDict[datalist[i][1]][datalist[i][3]] = [datalist[i][6]]      #12
#     dataDict[datalist[i][1]][datalist[i][3]] = [datalist[i][7]]     #14
#     dataDict[datalist[i][1]][datalist[i][3]] = [datalist[i][8]]    #16
    dataDict[datalist[i][1]][datalist[i][3]] = [datalist[i][9]]

print('dict length',len(dataDict))
# print(dataDict)
# print('dict2007', dataDict)
keyList = []
headData = dataDict['AFG']
keyList.append('Country Code')
for key, value in headData.items():
    keyList.append(key)
print('keylist length', len(keyList))
# print('keylist', keyList)

processDataList = []
for key, value in dataDict.items():
    dataDict[key]['Country Code'] = [key]
#     countrycode = key
    processDataList.append(dataDict[key])
#     print(dataDict[contrycode])
#     for inkey, invalue
# print('processDataList', processDataList)
# print('len processDataList', len(processDataList))
# print('len processDataList[0]', len(processDataList[0]))

finalDataFrame = pd.DataFrame(columns=keyList)
print(processDataList[0])
# result=result.append(pd.DataFrame({'idx':[i],'degree':[degree],'weight':[weight],'diameter':[diameter]}),ignore_index=True)
for i in range(len(processDataList)):
    finalDataFrame = finalDataFrame.append(pd.DataFrame(processDataList[i]))
finalDataFrame.set_index(['Country Code'], inplace=True)
print('finaldataframe', finalDataFrame)
finalDataFrame.isnull().sum(axis=0)
finalDataFrame = finalDataFrame.drop(['LP.LPI.OVRL.RK.LB','LP.LPI.OVRL.RK.UB','LP.LPI.OVRL.XQ.LB','LP.LPI.OVRL.XQ.UB'],axis=1)
# print(finalDataFrame.shape)

for column in list(finalDataFrame.columns[finalDataFrame.isnull().sum() > 0]):
    mean_val = finalDataFrame[column].mean()
    finalDataFrame[column].fillna(mean_val, inplace=True)
finalDataFrame.isnull().sum(axis=0)
# df.to_csv('d:/Users/chen_lib/Desktop/fenci_result.txt',sep='\t',index=False)
finalDataFrame.to_csv('processData/18Value.txt', sep='\t',index=False)
# Out:
# dict length 168
# keylist length 20
# {'LP.LPI.TRAC.RK': [159.0], 'LP.LPI.TRAC.XQ': [1.697024], 'LP.LPI.LOGS.RK': [158.0], 'LP.LPI.LOGS.XQ': [1.919246], 'LP.LPI.ITRN.RK': [152.0], 'LP.LPI.ITRN.XQ': [2.104431], 'LP.LPI.CUST.RK': [158.0], 'LP.LPI.CUST.XQ': [1.7349], 'LP.LPI.TIME.RK': [153.0], 'LP.LPI.TIME.XQ': [2.382438], 'LP.LPI.OVRL.RK': [160.0], 'LP.LPI.OVRL.RK.LB': [155.0], 'LP.LPI.OVRL.RK.UB': [160.0], 'LP.LPI.OVRL.XQ': [1.948565], 'LP.LPI.OVRL.XQ.LB': [1.7908509999999997], 'LP.LPI.OVRL.XQ.UB': [2.10628], 'LP.LPI.OVRL.RK.ZS': [29.6292860346769], 'LP.LPI.INFR.RK': [158.0], 'LP.LPI.INFR.XQ': [1.807143], 'Country Code': ['AFG']}
# d:\python3.6\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# finaldataframe               LP.LPI.CUST.RK  LP.LPI.CUST.XQ  LP.LPI.INFR.RK  LP.LPI.INFR.XQ  \
# Country Code
# AFG                    158.0        1.734900           158.0        1.807143
# AGO                    160.0        1.571429           153.0        1.857143
# ALB                    114.0        2.347126           110.0        2.293674
# ARE                     15.0        3.631403            10.0        4.021292
# ARG                     98.0        2.417844            62.0        2.773509
# ARM                     81.0        2.573787            86.0        2.484109
# AUS                      7.0        3.867186            16.0        3.968431
# AUT                     12.0        3.714068             5.0        4.181584
# AZE                      NaN             NaN             NaN             NaN
# BDI                    159.0        1.687500           146.0        1.952865
# BEL                     14.0        3.663064            14.0        3.984249
# BEN                     82.0        2.562500            83.0        2.496995
# BFA                    100.0        2.412879            95.0        2.430736
# BGD                    121.0        2.300000           100.0        2.388680
# BGR                     42.0        2.937588            64.0        2.762986
# BHR                     63.0        2.669956            68.0        2.724880
# BHS                     61.0        2.684211            98.0        2.408433
# BIH                     69.0        2.631579            97.0        2.421053
# BLR                    112.0        2.349962            92.0        2.440539
# BOL                    117.0        2.318927           129.0        2.152436
# BRA                    102.0        2.406162            50.0        2.926983
# BRN                     73.0        2.622014            89.0        2.460946
# BTN                    135.0        2.136382           150.0        1.908333
# BWA                      NaN             NaN             NaN             NaN
# CAF                    126.0        2.238095           148.0        1.928571
# CAN                     18.0        3.603930            21.0        3.750496
# CHE                     16.0        3.629262             9.0        4.021835
# CHL                     32.0        3.274026            34.0        3.209678
# CHN                     31.0        3.285924            20.0        3.753218
# CIV                     51.0        2.779167            56.0        2.886806
# ...                      ...             ...             ...             ...
# SLV                    120.0        2.301136           114.0        2.249457
# SOM                    145.0        2.000000           157.0        1.812865
# SRB                     78.0        2.597121            74.0        2.599877
# STP                     57.0        2.714286           106.0        2.330496
# SVK                     50.0        2.789011            48.0        3.000000
# SVN                     24.0        3.418681            31.0        3.261905
# SWE                      2.0        4.049361             3.0        4.239947
# SYR                    154.0        1.819048            82.0        2.514286
# TCD                    134.0        2.153846           104.0        2.372041
# TGO                    119.0        2.314394           116.0        2.232450
# THA                     36.0        3.142497            41.0        3.138133
# TJK                    150.0        1.923077           127.0        2.166173
# TKM                    111.0        2.350292           117.0        2.228861
# TLS                      NaN             NaN             NaN             NaN
# TTO                     96.0        2.423196           101.0        2.382692
# TUN                    107.0        2.375000           133.0        2.097569
# TUR                     58.0        2.713469            33.0        3.210029
# TWN                     22.0        3.474167            23.0        3.720193
# TZA                      NaN             NaN             NaN             NaN
# UGA                     76.0        2.610558           124.0        2.193993
# UKR                     89.0        2.491180           119.0        2.221296
# URY                     87.0        2.514882            94.0        2.433240
# USA                     10.0        3.775142             7.0        4.045132
# UZB                    140.0        2.103333            77.0        2.570000
# VEN                    156.0        1.787384           134.0        2.096936
# VNM                     41.0        2.950154            47.0        3.005490
# YEM                    104.0        2.400794           131.0        2.116794
# ZAF                     34.0        3.174600            36.0        3.186554
# ZMB                    129.0        2.180161           108.0        2.303431
# ZWE                    146.0        2.000000           154.0        1.833333
#
#               LP.LPI.ITRN.RK  LP.LPI.ITRN.XQ  LP.LPI.LOGS.RK  LP.LPI.LOGS.XQ  \
# Country Code
# AFG                    152.0        2.104431           158.0        1.919246
# AGO                    143.0        2.202283           155.0        2.004317
# ALB                     69.0        2.823862            92.0        2.558898
# ARE                      5.0        3.847370            13.0        3.919378
# ARG                     59.0        2.923781            68.0        2.777043
# ARM                     95.0        2.649059            97.0        2.503441
# AUS                     40.0        3.247206            21.0        3.709445
# AUT                      3.0        3.877530             6.0        4.083611
# AZE                      NaN             NaN             NaN             NaN
# BDI                    139.0        2.214416           117.0        2.332091
# BEL                      1.0        3.994913             2.0        4.130972
# BEN                     83.0        2.733894            98.0        2.502329
# BFA                     60.0        2.917749           106.0        2.459957
# BGD                    104.0        2.562778           102.0        2.483444
# BGR                     41.0        3.233723            55.0        2.881315
# BHR                     55.0        3.024256            58.0        2.857267
# BHS                    114.0        2.501450           130.0        2.267881
# BIH                     66.0        2.842105            65.0        2.801754
# BLR                    134.0        2.309091            85.0        2.641731
# BOL                    106.0        2.535217           139.0        2.210882
# BRA                     61.0        2.881091            46.0        3.090163
# BRN                    113.0        2.513390            77.0        2.709827
# BTN                    160.0        1.803902           115.0        2.346263
# BWA                      NaN             NaN             NaN             NaN
# CAF                    135.0        2.304762           157.0        1.928571
# CAN                     30.0        3.381662            14.0        3.898040
# CHE                     20.0        3.514933            11.0        3.966859
# CHL                     38.0        3.271893            43.0        3.125072
# CHN                     18.0        3.535715            27.0        3.594975
# CIV                     45.0        3.207318            37.0        3.227109
# ...                      ...             ...             ...             ...
# SLV                     86.0        2.710675            91.0        2.560868
# SOM                    100.0        2.612865           121.0        2.304539
# SRB                     57.0        2.971317            80.0        2.704650
# STP                    121.0        2.415986            84.0        2.646285
# SVK                     52.0        3.101099            41.0        3.139194
# SVN                     47.0        3.187912            50.0        3.052381
# SWE                      2.0        3.915837            10.0        3.976896
# SYR                    126.0        2.366300           124.0        2.289377
# TCD                    125.0        2.369527            86.0        2.619823
# TGO                    111.0        2.518939           134.0        2.249719
# THA                     25.0        3.456898            32.0        3.410726
# TJK                    133.0        2.312612           116.0        2.332840
# TKM                    136.0        2.287685           120.0        2.307501
# TLS                      NaN             NaN             NaN             NaN
# TTO                    101.0        2.586367           129.0        2.270751
# TUN                    115.0        2.497570           123.0        2.297570
# TUR                     53.0        3.060677            51.0        3.046799
# TWN                     24.0        3.476875            30.0        3.565054
# TZA                      NaN             NaN             NaN             NaN
# UGA                     78.0        2.760893            99.0        2.496367
# UKR                     68.0        2.829282            61.0        2.842631
# URY                     82.0        2.734974            78.0        2.708626
# USA                     23.0        3.506325            16.0        3.874253
# UZB                    120.0        2.423333            88.0        2.587714
# VEN                    123.0        2.379562           141.0        2.206915
# VNM                     49.0        3.155490            33.0        3.399340
# YEM                    141.0        2.206984           131.0        2.259524
# ZAF                     22.0        3.508124            39.0        3.192726
# ZMB                     54.0        3.052819           103.0        2.481390
# ZWE                    156.0        2.055556           147.0        2.160494
#
#               LP.LPI.OVRL.RK  LP.LPI.OVRL.RK.LB  LP.LPI.OVRL.RK.UB  \
# Country Code
# AFG                    160.0              155.0              160.0
# AGO                    159.0              142.0              160.0
# ALB                     88.0               64.0              115.0
# ARE                     11.0                2.0               15.0
# ARG                     61.0               57.0               72.0
# ARM                     92.0               73.0              122.0
# AUS                     18.0               14.0               26.0
# AUT                      4.0                2.0               14.0
# AZE                      NaN                NaN                NaN
# BDI                    158.0              139.0              160.0
# BEL                      3.0                2.0               12.0
# BEN                     76.0               58.0              109.0
# BFA                     91.0               61.0              133.0
# BGD                    100.0               68.0              134.0
# BGR                     52.0               40.0               64.0
# BHR                     59.0               48.0               76.0
# BHS                    112.0               85.0              130.0
# BIH                     72.0               56.0               91.0
# BLR                    103.0               78.0              125.0
# BOL                    131.0              113.0              146.0
# BRA                     56.0               48.0               64.0
# BRN                     80.0               60.0              114.0
# BTN                    149.0              129.0              159.0
# BWA                      NaN                NaN                NaN
# CAF                    151.0              116.0              160.0
# CAN                     20.0               14.0               27.0
# CHE                     13.0                7.0               17.0
# CHL                     34.0               31.0               41.0
# CHN                     26.0               23.0               27.0
# CIV                     50.0               38.0               63.0
# ...                      ...                ...                ...
# SLV                    101.0               82.0              118.0
# SOM                    144.0              117.0              159.0
# SRB                     65.0               50.0               96.0
# STP                     89.0               66.0              115.0
# SVK                     53.0               34.0               82.0
# SVN                     35.0               28.0               49.0
# SWE                      2.0                2.0               12.0
# SYR                    138.0              115.0              155.0
# TCD                    123.0               75.0              156.0
# TGO                    118.0               78.0              150.0
# THA                     32.0               29.0               37.0
# TJK                    134.0              108.0              151.0
# TKM                    126.0               97.0              141.0
# TLS                      NaN                NaN                NaN
# TTO                    124.0               93.0              143.0
# TUN                    105.0               75.0              129.0
# TUR                     47.0               40.0               51.0
# TWN                     27.0               18.0               31.0
# TZA                      NaN                NaN                NaN
# UGA                    102.0               73.0              133.0
# UKR                     66.0               52.0               91.0
# URY                     85.0               63.0              114.0
# USA                     14.0               12.0               17.0
# UZB                     99.0               75.0              129.0
# VEN                    142.0              130.0              156.0
# VNM                     39.0               31.0               48.0
# YEM                    140.0               80.0              160.0
# ZAF                     33.0               30.0               39.0
# ZMB                    111.0               84.0              130.0
# ZWE                    152.0              128.0              160.0
#
#               LP.LPI.OVRL.RK.ZS  LP.LPI.OVRL.XQ  LP.LPI.OVRL.XQ.LB  \
# Country Code
# AFG                   29.629286        1.948565           1.790851
# AGO                   32.677692        2.046158           1.847173
# ALB                   51.839201        2.659603           2.460908
# ARE                   92.346985        3.956437           3.859022
# ARG                   58.941653        2.886984           2.797332
# ARM                   50.215059        2.607607           2.418165
# AUS                   85.943437        3.751431           3.601817
# AUT                   94.520004        4.026005           3.884790
# AZE                         NaN             NaN                NaN
# BDI                   33.222789        2.063609           1.846792
# BEL                   94.928538        4.039084           3.919175
# BEN                   54.659366        2.749889           2.539084
# BFA                   50.647895        2.621464           2.341144
# BGD                   49.245934        2.576581           2.335623
# BGR                   63.532737        3.033965           2.841196
# BHR                   60.435760        2.934817           2.746803
# BHS                   47.647624        2.525412           2.365442
# BIH                   56.492164        2.808565           2.615623
# BLR                   49.185086        2.574633           2.411342
# BOL                   42.430103        2.358376           2.194252
# BRA                   62.027947        2.985790           2.846858
# BRN                   53.305852        2.706557           2.507244
# BTN                   36.514148        2.168980           1.950659
# BWA                         NaN             NaN                NaN
# CAF                   35.869970        2.148357           1.813745
# CAN                   85.171410        3.726715           3.560903
# CHE                   90.626980        3.901372           3.798316
# CHL                   72.378121        3.317145           3.207844
# CHN                   81.374124        3.605147           3.547488
# CIV                   65.041056        3.082253           2.860591
# ...                         ...             ...                ...
# SLV                   49.212824        2.575521           2.447198
# SOM                   37.754120        2.208677           1.967034
# SRB                   57.503833        2.840953           2.589503
# STP                   51.639416        2.653207           2.470064
# SVK                   63.319240        3.027130           2.694342
# SVN                   72.304248        3.314780           3.084186
# SWE                   95.360250        4.052905           3.904824
# SYR                   40.467395        2.295541           2.084718
# TCD                   44.274927        2.417437           2.073582
# TGO                   45.212754        2.447461           2.157820
# THA                   75.311578        3.411058           3.291623
# TJK                   41.842306        2.339558           2.123195
# TKM                   44.036504        2.409804           2.229772
# TLS                         NaN             NaN                NaN
# TTO                   44.218859        2.415642           2.224108
# TUN                   49.026221        2.569547           2.375774
# TUR                   67.026286        3.145809           3.048446
# TWN                   81.204669        3.599722           3.416402
# TZA                         NaN             NaN                NaN
# UGA                   49.209201        2.575405           2.342655
# UKR                   57.167266        2.830178           2.621232
# URY                   52.635217        2.685087           2.504859
# USA                   90.119615        3.885129           3.829968
# UZB                   49.267018        2.577256           2.380418
# VEN                   38.395674        2.229216           2.076098
# VNM                   71.029823        3.273980           3.110737
# YEM                   39.521385        2.265255           1.823761
# ZAF                   74.219946        3.376110           3.245321
# ZMB                   47.675768        2.526313           2.361903
# ZWE                   34.987993        2.120121           1.841924
#
#               LP.LPI.OVRL.XQ.UB  LP.LPI.TIME.RK  LP.LPI.TIME.XQ  \
# Country Code
# AFG                    2.106280           153.0        2.382438
# AGO                    2.245143           140.0        2.594983
# ALB                    2.858299            73.0        3.202666
# ARE                    4.053852             4.0        4.376292
# ARG                    2.976636            58.0        3.368942
# ARM                    2.797050           111.0        2.896062
# AUS                    3.901046            21.0        3.976111
# AUT                    4.167221            12.0        4.250803
# AZE                         NaN             NaN             NaN
# BDI                    2.280425           158.0        2.165472
# BEL                    4.158993             1.0        4.410293
# BEN                    2.960693            57.0        3.415745
# BFA                    2.901783            95.0        3.037879
# BGD                    2.817538           107.0        2.923681
# BGR                    3.226735            65.0        3.313491
# BHR                    3.122831            68.0        3.285448
# BHS                    2.685381           125.0        2.751119
# BIH                    3.001508            72.0        3.210526
# BLR                    2.737924            78.0        3.176941
# BOL                    2.522500           127.0        2.742127
# BRA                    3.124723            51.0        3.510178
# BRN                    2.905870            80.0        3.173628
# BTN                    2.387302           146.0        2.486475
# BWA                         NaN             NaN             NaN
# CAF                    2.482968           156.0        2.333333
# CAN                    3.892527            22.0        3.960503
# CHE                    4.004429            13.0        4.241830
# CHL                    3.426447            31.0        3.797014
# CHN                    3.662806            27.0        3.840015
# CIV                    3.303915            71.0        3.227109
# ...                         ...             ...             ...
# SLV                    2.703845            90.0        3.098685
# SOM                    2.450320           157.0        2.204196
# SRB                    3.092404            62.0        3.333418
# STP                    2.836349            97.0        3.014706
# SVK                    3.359917            86.0        3.139194
# SVN                    3.545375            38.0        3.695238
# SWE                    4.200986             7.0        4.284866
# SYR                    2.506364           148.0        2.443223
# TCD                    2.761292           138.0        2.619823
# TGO                    2.737102           112.0        2.878886
# THA                    3.530493            28.0        3.813817
# TJK                    2.555921           104.0        2.948976
# TKM                    2.589836           130.0        2.718650
# TLS                         NaN             NaN             NaN
# TTO                    2.607176           144.0        2.531926
# TUN                    2.763321            70.0        3.236042
# TUR                    3.243172            44.0        3.628118
# TWN                    3.783043            35.0        3.720617
# TZA                         NaN             NaN             NaN
# UGA                    2.808156           110.0        2.899217
# UKR                    3.039124            56.0        3.422145
# URY                    2.865315           109.0        2.906435
# USA                    3.940291            19.0        4.083623
# UZB                    2.774094            91.0        3.090000
# VEN                    2.382333           141.0        2.581759
# VNM                    3.437223            40.0        3.672003
# YEM                    2.706749           151.0        2.426191
# ZAF                    3.506900            34.0        3.742441
# ZMB                    2.690722            94.0        3.052819
# ZWE                    2.398318           152.0        2.385957
#
#               LP.LPI.TRAC.RK  LP.LPI.TRAC.XQ
# Country Code
# AFG                    159.0        1.697024
# AGO                    157.0        2.004317
# ALB                     95.0        2.665647
# ARE                     13.0        3.960279
# ARG                     58.0        3.046989
# ARM                    113.0        2.511196
# AUS                     20.0        3.816621
# AUT                      7.0        4.087098
# AZE                      NaN             NaN
# BDI                    156.0        2.006542
# BEL                      9.0        4.051289
# BEN                     87.0        2.748422
# BFA                    124.0        2.401515
# BGD                     79.0        2.785000
# BGR                     59.0        3.015289
# BHR                     60.0        3.012881
# BHS                    110.0        2.517881
# BIH                     70.0        2.894737
# BLR                    109.0        2.536468
# BOL                    148.0        2.131688
# BRA                     51.0        3.111438
# BRN                     88.0        2.747244
# BTN                    130.0        2.346263
# BWA                      NaN             NaN
# CAF                    151.0        2.104762
# CAN                     21.0        3.809804
# CHE                      5.0        4.096271
# CHL                     44.0        3.203612
# CHN                     27.0        3.648469
# CIV                     49.0        3.136200
# ...                      ...             ...
# SLV                    117.0        2.471675
# SOM                    140.0        2.233110
# SRB                     76.0        2.789011
# STP                     81.0        2.783317
# SVK                     64.0        2.985348
# SVN                     40.0        3.266667
# SWE                     17.0        3.876315
# SYR                    128.0        2.366300
# TCD                    127.0        2.372041
# TGO                    120.0        2.449635
# THA                     33.0        3.467161
# TJK                    131.0        2.332840
# TKM                    107.0        2.557501
# TLS                      NaN             NaN
# TTO                    135.0        2.267067
# TUN                     71.0        2.864583
# TUR                     42.0        3.233056
# TWN                     25.0        3.670812
# TZA                      NaN             NaN
# UGA                    123.0        2.414145
# UKR                     52.0        3.109298
# URY                     82.0        2.780353
# USA                      6.0        4.091751
# UZB                     90.0        2.709048
# VEN                    133.0        2.294127
# VNM                     34.0        3.449780
# YEM                    146.0        2.161905
# ZAF                     35.0        3.411336
# ZMB                    158.0        1.981390
# ZWE                    137.0        2.262147
#
# [168 rows x 19 columns]
